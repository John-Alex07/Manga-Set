# %%
from transformers import AutoModel, AutoConfig

# Set the cache directory
cache_dir = "J:\\Important\\VIT Vellore\\SET PROJECT\\cache"

# Load the model using the specified cache directory
config = AutoConfig.from_pretrained("stabilityai/stable-diffusion-2-1", cache_dir=cache_dir)
model = AutoModel.from_pretrained("stabilityai/stable-diffusion-2-1", config=config, cache_dir=cache_dir)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 7
#       4 cache_dir = "J:\\Important\\VIT Vellore\\SET PROJECT\\cache"
#       6 # Load the model using the specified cache directory
# ----> 7 config = AutoConfig.from_pretrained("stabilityai/stable-diffusion-2-1", cache_dir=cache_dir)
#       8 model = AutoModel.from_pretrained("stabilityai/stable-diffusion-2-1", config=config, cache_dir=cache_dir)
#
# File j:\Important\VIT Vellore\SET PROJECT\manga-project_backend\.venv\lib\site-packages\transformers\models\auto\configuration_auto.py:1091, in AutoConfig.from_pretrained(cls, pretrained_model_name_or_path, **kwargs)
#    1088         if pattern in str(pretrained_model_name_or_path):
#    1089             return CONFIG_MAPPING[pattern].from_dict(config_dict, **unused_kwargs)
# -> 1091 raise ValueError(
# ...

# %%
from diffusers import StableDiffusionPipeline
import torch
# Set the cache directory
cache_dir = "J:\\Important\\VIT Vellore\\SET PROJECT\\cache"

# Load the Stable Diffusion pipeline using the specified cache directory
model_name = "stabilityai/stable-diffusion-2-1"
pipeline = StableDiffusionPipeline.from_pretrained(model_name, cache_dir=cache_dir, torch_dtype=torch.float16)
# Out:
# Loading pipeline components...:   0%|          | 0/6 [00:00<?, ?it/s]

# %%
pipeline = pipeline.to("cuda")

# %%
if torch.cuda.is_available():
    print("CUDA is available")
else:
    print("CUDA is not available")
# Out:
# CUDA is available

# %%
prompt = """
Clear Highly detailed manga-style art of a 16-year-old teenage boy with messy hair and a visible cut on his cheek. He wears a slightly torn school uniform. Defensive stance, fists clenched, eyes full of determination, showing fear and courage. Dramatic lighting, high contrast shading, crisp linework, and expressive details. Professional manga art, ultra-detailed"""

image = pipeline(prompt).images[0]

image.show()
# Out:
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['detailed']
#   0%|          | 0/50 [00:00<?, ?it/s]
