# %%
import torch
from diffusers import StableDiffusion3Pipeline

cache_dir = "J:\Important\VIT Vellore\SET PROJECT\cache"
model_name = "stabilityai/stable-diffusion-3.5-large-turbo"

# tokenizer = AutoTokenizer.from_pretrained(model_name, cache_dir=cache_dir)
pipe = StableDiffusion3Pipeline.from_pretrained(model_name,  cache_dir=cache_dir,torch_dtype=torch.bfloat16)
pipe = pipe.to("cuda")
# Out:
# Loading pipeline components...:   0%|          | 0/9 [00:00<?, ?it/s]
# You set `add_prefix_space`. The tokenizer needs to be converted from the slow tokenizers
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[1], line 8
#       5 model_name = "stabilityai/stable-diffusion-3.5-large-turbo"
#       7 # tokenizer = AutoTokenizer.from_pretrained(model_name, cache_dir=cache_dir)
# ----> 8 pipe = StableDiffusion3Pipeline.from_pretrained(model_name,  cache_dir=cache_dir,torch_dtype=torch.bfloat16)
#       9 pipe = pipe.to("cuda")
#
# File j:\Important\VIT Vellore\SET PROJECT\manga-project_backend\.venv\lib\site-packages\huggingface_hub\utils\_validators.py:114, in validate_hf_hub_args.<locals>._inner_fn(*args, **kwargs)
#     111 if check_use_auth_token:
#     112     kwargs = smoothly_deprecate_use_auth_token(fn_name=fn.__name__, has_token=has_token, kwargs=kwargs)
# --> 114 return fn(*args, **kwargs)
#
# File j:\Important\VIT Vellore\SET PROJECT\manga-project_backend\.venv\lib\site-packages\diffusers\pipelines\pipeline_utils.py:924, in DiffusionPipeline.from_pretrained(cls, pretrained_model_name_or_path, **kwargs)
#     921     loaded_sub_model = passed_class_obj[name]
#     922 else:
#     923     # load sub model
# --> 924     loaded_sub_model = load_sub_model(
#     925         library_name=library_name,
#     926         class_name=class_name,
#     927         importable_classes=importable_classes,
#     928         pipelines=pipelines,
#     929         is_pipeline_module=is_pipeline_module,
#     930         pipeline_class=pipeline_class,
#     931         torch_dtype=torch_dtype,
#     932         provider=provider,
#     933         sess_options=sess_options,
#     934         device_map=current_device_map,
#     935         max_memory=max_memory,
#     936         offload_folder=offload_folder,
#     937         offload_state_dict=offload_state_dict,
#     938         model_variants=model_variants,
#     939         name=name,
#     940         from_flax=from_flax,
#     941         variant=variant,
#     942         low_cpu_mem_usage=low_cpu_mem_usage,
#     943         cached_folder=cached_folder,
#     944         use_safetensors=use_safetensors,
#     945     )
#     946     logger.info(
#     947         f"Loaded {name} as {class_name} from `{name}` subfolder of {pretrained_model_name_or_path}."
#     948     )
#     950 init_kwargs[name] = loaded_sub_model  # UNet(...), # DiffusionSchedule(...)
#
# File j:\Important\VIT Vellore\SET PROJECT\manga-project_backend\.venv\lib\site-packages\diffusers\pipelines\pipeline_loading_utils.py:725, in load_sub_model(library_name, class_name, importable_classes, pipelines, is_pipeline_module, pipeline_class, torch_dtype, provider, sess_options, device_map, max_memory, offload_folder, offload_state_dict, model_variants, name, from_flax, variant, low_cpu_mem_usage, cached_folder, use_safetensors)
#     723 # check if the module is in a subdirectory
#     724 if os.path.isdir(os.path.join(cached_folder, name)):
# --> 725     loaded_sub_model = load_method(os.path.join(cached_folder, name), **loading_kwargs)
#     726 else:
#     727     # else load from the root directory
#     728     loaded_sub_model = load_method(cached_folder, **loading_kwargs)
#
# File j:\Important\VIT Vellore\SET PROJECT\manga-project_backend\.venv\lib\site-packages\transformers\modeling_utils.py:4245, in PreTrainedModel.from_pretrained(cls, pretrained_model_name_or_path, config, cache_dir, ignore_mismatched_sizes, force_download, local_files_only, token, revision, use_safetensors, weights_only, *model_args, **kwargs)
#    4235         load_contexts.append(tp_device)
#    4237     with ContextManagers(load_contexts):
#    4238         (
#    4239             model,
#    4240             missing_keys,
#    4241             unexpected_keys,
#    4242             mismatched_keys,
#    4243             offload_index,
#    4244             error_msgs,
# -> 4245         ) = cls._load_pretrained_model(
#    4246             model,
#    4247             state_dict,
#    4248             loaded_state_dict_keys,  # XXX: rename?
#    4249             resolved_archive_file,
#    4250             pretrained_model_name_or_path,
#    4251             ignore_mismatched_sizes=ignore_mismatched_sizes,
#    4252             sharded_metadata=sharded_metadata,
#    4253             _fast_init=_fast_init,
#    4254             low_cpu_mem_usage=low_cpu_mem_usage,
#    4255             device_map=device_map,
#    4256             offload_folder=offload_folder,
#    4257             offload_state_dict=offload_state_dict,
#    4258             dtype=torch_dtype,
#    4259             hf_quantizer=hf_quantizer,
#    4260             keep_in_fp32_modules=keep_in_fp32_modules,
#    4261             gguf_path=gguf_path,
#    4262             weights_only=weights_only,
#    4263         )
#    4265 # make sure token embedding weights are still tied if needed
#    4266 model.tie_weights()
#
# File j:\Important\VIT Vellore\SET PROJECT\manga-project_backend\.venv\lib\site-packages\transformers\modeling_utils.py:4791, in PreTrainedModel._load_pretrained_model(***failed resolving arguments***)
#    4784 if (
#    4785     device_map is not None
#    4786     and hf_quantizer is not None
#    4787     and hf_quantizer.quantization_config.quant_method == QuantizationMethod.TORCHAO
#    4788     and hf_quantizer.quantization_config.quant_type == "int4_weight_only"
#    4789 ):
#    4790     map_location = torch.device([d for d in device_map.values() if d not in ["cpu", "disk"]][0])
# -> 4791 state_dict = load_state_dict(
#    4792     shard_file, is_quantized=is_quantized, map_location=map_location, weights_only=weights_only
#    4793 )
#    4795 # Mistmatched keys contains tuples key/shape1/shape2 of weights in the checkpoint that have a shape not
#    4796 # matching the weights in the model.
#    4797 mismatched_keys += _find_mismatched_keys(
#    4798     state_dict,
#    4799     model_state_dict,
#    (...)
#    4804     ignore_mismatched_sizes,
#    4805 )
#
# File j:\Important\VIT Vellore\SET PROJECT\manga-project_backend\.venv\lib\site-packages\transformers\modeling_utils.py:504, in load_state_dict(checkpoint_file, is_quantized, map_location, weights_only)
#     499 """
#     500 Reads a PyTorch checkpoint file, returning properly formatted errors if they arise.
#     501 """
#     502 if checkpoint_file.endswith(".safetensors") and is_safetensors_available():
#     503     # Check format of the archive
# --> 504     with safe_open(checkpoint_file, framework="pt") as f:
#     505         metadata = f.metadata()
#     506     if metadata is not None and metadata.get("format") not in ["pt", "tf", "flax", "mlx"]:
#
# OSError: The paging file is too small for this operation to complete. (os error 1455)

# %%
# pipeline.enable_model_cpu_offload()

prompt = "A whimsical and creative image depicting a hybrid creature that is a mix of a waffle and a hippopotamus, basking in a river of melted butter amidst a breakfast-themed landscape. It features the distinctive, bulky body shape of a hippo. However, instead of the usual grey skin, the creature's body resembles a golden-brown, crispy waffle fresh off the griddle. The skin is textured with the familiar grid pattern of a waffle, each square filled with a glistening sheen of syrup. The environment combines the natural habitat of a hippo with elements of a breakfast table setting, a river of warm, melted butter, with oversized utensils or plates peeking out from the lush, pancake-like foliage in the background, a towering pepper mill standing in for a tree.  As the sun rises in this fantastical world, it casts a warm, buttery glow over the scene. The creature, content in its butter river, lets out a yawn. Nearby, a flock of birds take flight"

image = pipe(
    prompt=prompt,
    num_inference_steps=4,
    guidance_scale=0.0,
    max_sequence_length=512,
).images[0]
image.save("whimsical.png")

# %%
import bitsandbytes as bnb
print(bnb.__version__)
